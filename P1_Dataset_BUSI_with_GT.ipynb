# %% [markdown]
# <a href="https://colab.research.google.com/github/cvjeongwon/TensorFlow2/blob/main/P1_Dataset_BUSI_with_GT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Google Drive 마운트해서 데이터셋 가져옴

# %%
from google.colab import drive   

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # ROOT_DIR, DATA_ROOT_DIR 설정

# %%
import os

ROOT_DIR = '/content'

DATA_ROOT_DIR = os.path.join(ROOT_DIR, 'Dataset_BUSI_with_GT')  

CLASSIFICATION_DATA_ROOT_DIR = os.path.join(ROOT_DIR, 'Classification')

CLASSIFICATION_TRAIN_DATA_ROOT_DIR = os.path.join(CLASSIFICATION_DATA_ROOT_DIR, 'train')

# %%
import shutil

if os.path.exists(DATA_ROOT_DIR):        
    shutil.rmtree(DATA_ROOT_DIR) 

if os.path.exists(CLASSIFICATION_DATA_ROOT_DIR):    
    shutil.rmtree(CLASSIFICATION_DATA_ROOT_DIR)

# %% [markdown]
# # Google Drive 에서 dataset download

# %%
import shutil
import os

try:
    dataset_path = '/content/gdrive/My Drive/Colab Notebooks/dataset'
    
    shutil.copy(os.path.join(dataset_path, 'Dataset_BUSI_with_GT.zip'), '/content')

except Exception as err:
    print(str(err))

# %%
import zipfile

with zipfile.ZipFile(os.path.join(ROOT_DIR, 'Dataset_BUSI_with_GT.zip'), 'r') as target_file:

    target_file.extractall(DATA_ROOT_DIR)

# %% [markdown]
# # '/content/Dataset_BUSI_with_G' Dataset_BUSI_with_G 디렉토리의 서브디렉토리와 그 내용을 삭제
# import os
#
# # path = '/content/Classification/train/Dataset_BUSI_with_GT'
# path = '/content/Classification'
#
# for root, dirs, files in os.walk(path, topdown=False):
#     for name in dirs:
#         shutil.rmtree(os.path.join(root, name))
#         os.rmdir(os.path.join(root,name))

# %%
import shutil
import os
import glob

total_file_list = glob.glob(os.path.join(DATA_ROOT_DIR+'/Dataset_BUSI_with_GT', '*'))

label_name_list = [ file_name.split('/')[-1].strip()  for file_name in total_file_list  if os.path.isdir(file_name) == True ]


if not os.path.exists(CLASSIFICATION_DATA_ROOT_DIR):  
    os.mkdir(CLASSIFICATION_DATA_ROOT_DIR)
    os.mkdir(CLASSIFICATION_TRAIN_DATA_ROOT_DIR)

for label_name in label_name_list:

    src_dir_path = os.path.join(DATA_ROOT_DIR+'/Dataset_BUSI_with_GT', label_name)
    dst_dir_path = os.path.join(CLASSIFICATION_TRAIN_DATA_ROOT_DIR, label_name)
    try:
        shutil.copytree(src_dir_path, dst_dir_path)
    except Exception as err:
        print(str(err))

train_label_name_list = os.listdir(CLASSIFICATION_TRAIN_DATA_ROOT_DIR)

for label_name in train_label_name_list:
    print('train label : ', label_name,' => ', len(os.listdir(os.path.join(CLASSIFICATION_TRAIN_DATA_ROOT_DIR, label_name))))
# Out:
# train label :  benign  =>  437
# train label :  normal  =>  133
# train label :  malignant  =>  210

# %% [markdown]
# #### Classification 데이터 생성

# %%
import os
import glob
import pandas as pd

train_label_name_list = os.listdir(CLASSIFICATION_TRAIN_DATA_ROOT_DIR)

for label_name in train_label_name_list:    

    temp_dic = {}    

    file_list = glob.glob(CLASSIFICATION_TRAIN_DATA_ROOT_DIR+'/'+label_name+'/*')

    temp_dic[label_name] = file_list    # temp_dic['label_name'] = [ file_name, ... ]

    temp_df = pd.DataFrame(temp_dic)

    image_file_df = temp_df[~temp_df[label_name].str.contains('_mask')].reset_index(drop=True)

    mask_file_df = temp_df[temp_df[label_name].str.contains('_mask')].reset_index(drop=True)

    print('label = ', label_name, ' , image  = ', len(image_file_df), ' , mask = ', len(mask_file_df))
    
    for row in range(len(mask_file_df)):

        try:
            os.remove(mask_file_df.loc[row,label_name])
        except Exception as err:
            print(str(err))
# Out:
# label =  benign  , image  =  437  , mask =  0
# label =  normal  , image  =  133  , mask =  0
# label =  malignant  , image  =  210  , mask =  0

# %% [markdown]
# # Classification 에서 Data Augmentation 하기 위한 전체 데이터 개수 계산

# %%
import os

train_label_name_list = os.listdir(CLASSIFICATION_TRAIN_DATA_ROOT_DIR)

total_image_data_nums = 0

for label_name in train_label_name_list:    # 각각의 정답(label)에 대해서

    image_data_nums = len(os.listdir(os.path.join(CLASSIFICATION_TRAIN_DATA_ROOT_DIR, label_name)))

    print('label = ', label_name, ' , data nums = ', image_data_nums)
    
    total_image_data_nums += image_data_nums

print('total image data nums = ', total_image_data_nums)
# Out:
# label =  benign  , data nums =  437
# label =  normal  , data nums =  133
# label =  malignant  , data nums =  210
# total image data nums =  780

# %%
TOTAL_TRAIN_IMAGE_DATA_NUMS = total_image_data_nums

# %%
original_gen = ImageDataGenerator(rescale=1./255)  

original_generator = original_gen.flow_from_directory(CLASSIFICATION_TRAIN_DATA_ROOT_DIR,
                                   batch_size=TOTAL_TRAIN_IMAGE_DATA_NUMS, shuffle=False,
                                   target_size=(224, 224), class_mode='sparse')
# Out:
# Found 780 images belonging to 3 classes.

# %%
x_train, y_train = original_generator.next()

print(x_train.shape, y_train.shape)
# Out:
# (780, 224, 224, 3) (780,)

# %% [markdown]
# #### Augmentation Data 생성

# %%
AUGMENTATION_COUNT = 4    # 원본 데이터의 4배 증대

# %%
augmentation_gen = ImageDataGenerator(rescale=1./255, rotation_range=10, shear_range=0.1, zoom_range=0.1,
                                      horizontal_flip=True, width_shift_range=0.1, height_shift_range=0.1)

augmentation_generator = augmentation_gen.flow_from_directory(CLASSIFICATION_TRAIN_DATA_ROOT_DIR,
                                   batch_size=TOTAL_TRAIN_IMAGE_DATA_NUMS, shuffle=False,
                                   target_size=(224, 224), class_mode='sparse')
# Out:
# Found 780 images belonging to 3 classes.

# %%
import numpy as np

print('====================================================')
print('[bofore] ', x_train.shape, y_train.shape)
print('====================================================')

for i in range(AUGMENTATION_COUNT):    # 780개의 전체 데이터에 대해서 AUGMENTATION_COUNT 배 AUGMENTATION 실행

    x_augmented, y_augmented = augmentation_generator.next()

    x_train = np.concatenate( (x_train, x_augmented) )
    y_train = np.concatenate( (y_train, y_augmented) )

print('[after] ', x_train.shape, y_train.shape)    # 780*4+780 = 3900 
print('====================================================')
# Out:
# ====================================================
# [bofore]  (780, 224, 224, 3) (780,)
# ====================================================
# [after]  (3900, 224, 224, 3) (3900,)
# ====================================================

# %%
# x_train.shape[0]
np.random.shuffle(np.arange(x_train.shape[0]))

# %% [markdown]
# # train data random shuffle

# %%
s = np.arange(x_train.shape[0])

np.random.shuffle(s)

x_train = x_train[s]
y_train = y_train[s]

# %%
SPLIT_RATIO = 0.2    # train : test = 8 : 2

# %%
split_num = int(SPLIT_RATIO*(x_train.shape[0]))

x_test = x_train[:split_num]

y_test = y_train[:split_num]

print(x_test.shape, y_test.shape)
# Out:
# (780, 224, 224, 3) (780,)

# %%
x_train = x_train[split_num:]

y_train = y_train[split_num:]

print(x_train.shape, y_train.shape)
# Out:
# (3120, 224, 224, 3) (3120,)

# %% [markdown]
# # 16 개의 데이터와 정답 출력

# %%
import matplotlib.pyplot as plt

class_dict = {0:'benign', 1:'malignant', 2:'normal'}

plt.figure(figsize=(8,8))

for i in range(16):

    plt.subplot(4, 4, i+1)
    plt.title(str(class_dict[int(y_train[i])]))
    plt.xticks([]) 
    plt.yticks([])

    plt.imshow(x_train[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# # IMAGE SHAPE 설정

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224

# %% [markdown]
# # Fine Tuning 위한 pre-trained model 정의 및 모델 구축

# %%
class_nums = original_generator.num_classes

pre_trained_model = MobileNet(weights='imagenet', include_top=False, input_shape=(IMG_WIDTH,IMG_HEIGHT,3))

model = Sequential()

model.add(pre_trained_model)

model.add(GlobalAveragePooling2D())

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))  

model.add(Dense(class_nums, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  global_average_pooling2d (G  (None, 1024)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 3,524,547
# Trainable params: 3,502,659
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(2e-5), metrics=['acc'])

# %%
hist = model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 98/98 [==============================] - 42s 149ms/step - loss: 1.4447 - acc: 0.4385 - val_loss: 0.8694 - val_acc: 0.5936
# Epoch 2/50
# 98/98 [==============================] - 12s 122ms/step - loss: 1.0242 - acc: 0.5679 - val_loss: 0.7979 - val_acc: 0.6359
# Epoch 3/50
# 98/98 [==============================] - 12s 122ms/step - loss: 0.8334 - acc: 0.6378 - val_loss: 0.7131 - val_acc: 0.6718
# Epoch 4/50
# 98/98 [==============================] - 12s 119ms/step - loss: 0.6904 - acc: 0.6968 - val_loss: 0.6361 - val_acc: 0.7218
# Epoch 5/50
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5813 - acc: 0.7590 - val_loss: 0.5291 - val_acc: 0.7936
# Epoch 6/50
# 98/98 [==============================] - 12s 120ms/step - loss: 0.5089 - acc: 0.7862 - val_loss: 0.4269 - val_acc: 0.8372
# Epoch 7/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.4396 - acc: 0.8253 - val_loss: 0.3603 - val_acc: 0.8564
# Epoch 8/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.3742 - acc: 0.8481 - val_loss: 0.3284 - val_acc: 0.8782
# Epoch 9/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.3261 - acc: 0.8760 - val_loss: 0.2907 - val_acc: 0.8859
# Epoch 10/50
# 98/98 [==============================] - 12s 121ms/step - loss: 0.2856 - acc: 0.8853 - val_loss: 0.2720 - val_acc: 0.8949
# Epoch 11/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.2433 - acc: 0.9202 - val_loss: 0.2393 - val_acc: 0.9051
# Epoch 12/50
# 98/98 [==============================] - 12s 122ms/step - loss: 0.2224 - acc: 0.9244 - val_loss: 0.2219 - val_acc: 0.9141
# Epoch 13/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.1850 - acc: 0.9359 - val_loss: 0.2179 - val_acc: 0.9205
# Epoch 14/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.1530 - acc: 0.9478 - val_loss: 0.1965 - val_acc: 0.9269
# Epoch 15/50
# 98/98 [==============================] - 12s 122ms/step - loss: 0.1332 - acc: 0.9577 - val_loss: 0.1803 - val_acc: 0.9282
# Epoch 16/50
# 98/98 [==============================] - 12s 122ms/step - loss: 0.1007 - acc: 0.9702 - val_loss: 0.1736 - val_acc: 0.9346
# Epoch 17/50
# 98/98 [==============================] - 12s 127ms/step - loss: 0.0942 - acc: 0.9718 - val_loss: 0.1683 - val_acc: 0.9423
# Epoch 18/50
# 98/98 [==============================] - 12s 127ms/step - loss: 0.0782 - acc: 0.9785 - val_loss: 0.1508 - val_acc: 0.9385
# Epoch 19/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0654 - acc: 0.9843 - val_loss: 0.1437 - val_acc: 0.9423
# Epoch 20/50
# 98/98 [==============================] - 13s 128ms/step - loss: 0.0527 - acc: 0.9865 - val_loss: 0.1358 - val_acc: 0.9474
# Epoch 21/50
# 98/98 [==============================] - 13s 128ms/step - loss: 0.0464 - acc: 0.9885 - val_loss: 0.1363 - val_acc: 0.9474
# Epoch 22/50
# 98/98 [==============================] - 13s 128ms/step - loss: 0.0454 - acc: 0.9881 - val_loss: 0.1356 - val_acc: 0.9500
# Epoch 23/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0441 - acc: 0.9878 - val_loss: 0.1333 - val_acc: 0.9436
# Epoch 24/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0364 - acc: 0.9901 - val_loss: 0.1270 - val_acc: 0.9538
# Epoch 25/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0331 - acc: 0.9907 - val_loss: 0.1320 - val_acc: 0.9474
# Epoch 26/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0307 - acc: 0.9910 - val_loss: 0.1350 - val_acc: 0.9487
# Epoch 27/50
# 98/98 [==============================] - 13s 128ms/step - loss: 0.0228 - acc: 0.9946 - val_loss: 0.1366 - val_acc: 0.9603
# Epoch 28/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0188 - acc: 0.9971 - val_loss: 0.1343 - val_acc: 0.9474
# Epoch 29/50
# 98/98 [==============================] - 13s 128ms/step - loss: 0.0185 - acc: 0.9955 - val_loss: 0.1286 - val_acc: 0.9538
# Epoch 30/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0164 - acc: 0.9968 - val_loss: 0.1318 - val_acc: 0.9564
# Epoch 31/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.0164 - acc: 0.9968 - val_loss: 0.1410 - val_acc: 0.9590
# Epoch 32/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0146 - acc: 0.9965 - val_loss: 0.1245 - val_acc: 0.9641
# Epoch 33/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0125 - acc: 0.9974 - val_loss: 0.1301 - val_acc: 0.9628
# Epoch 34/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0119 - acc: 0.9974 - val_loss: 0.1343 - val_acc: 0.9538
# Epoch 35/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0125 - acc: 0.9974 - val_loss: 0.1371 - val_acc: 0.9590
# Epoch 36/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0078 - acc: 0.9990 - val_loss: 0.1448 - val_acc: 0.9590
# Epoch 37/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0086 - acc: 0.9984 - val_loss: 0.1429 - val_acc: 0.9603
# Epoch 38/50
# 98/98 [==============================] - 13s 129ms/step - loss: 0.0094 - acc: 0.9987 - val_loss: 0.1385 - val_acc: 0.9615
# Epoch 39/50
# 98/98 [==============================] - 13s 130ms/step - loss: 0.0088 - acc: 0.9978 - val_loss: 0.1450 - val_acc: 0.9603
# Epoch 40/50
# 98/98 [==============================] - 13s 129ms/step - loss: 0.0078 - acc: 0.9978 - val_loss: 0.1322 - val_acc: 0.9615
# Epoch 41/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0073 - acc: 0.9990 - val_loss: 0.1391 - val_acc: 0.9615
# Epoch 42/50
# 98/98 [==============================] - 12s 124ms/step - loss: 0.0092 - acc: 0.9978 - val_loss: 0.1440 - val_acc: 0.9628
# Epoch 43/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0106 - acc: 0.9968 - val_loss: 0.1618 - val_acc: 0.9564
# Epoch 44/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.0077 - acc: 0.9981 - val_loss: 0.1718 - val_acc: 0.9487
# Epoch 45/50
# 98/98 [==============================] - 13s 130ms/step - loss: 0.0053 - acc: 0.9990 - val_loss: 0.1499 - val_acc: 0.9564
# Epoch 46/50
# 98/98 [==============================] - 13s 130ms/step - loss: 0.0041 - acc: 0.9994 - val_loss: 0.1463 - val_acc: 0.9603
# Epoch 47/50
# 98/98 [==============================] - 12s 125ms/step - loss: 0.0059 - acc: 0.9984 - val_loss: 0.1484 - val_acc: 0.9615
# Epoch 48/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.0049 - acc: 0.9994 - val_loss: 0.1343 - val_acc: 0.9667
# Epoch 49/50
# 98/98 [==============================] - 12s 126ms/step - loss: 0.0059 - acc: 0.9978 - val_loss: 0.1436 - val_acc: 0.9667
# Epoch 50/50
# 98/98 [==============================] - 13s 130ms/step - loss: 0.0068 - acc: 0.9981 - val_loss: 0.1836 - val_acc: 0.9500

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['acc'], label='train')
plt.plot(hist.history['val_acc'], label='validation')
plt.title('Accuracy Trend')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='validation')
plt.title('Loss Trend')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.grid()
plt.show()

# %%
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0000e+00 - acc: 0.0000e+00
# [0.0, 0.0]
